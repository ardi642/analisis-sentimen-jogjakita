# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
root_path = '/content/gdrive/My Drive/KULIAH SEMESTER 8/KODING PENELITIAN SKRIPSI/'

# %%
import sys
sys.path.append(root_path)

# %%
import pandas as pd

df = pd.read_csv(root_path + 'cleaning_dataset_autolabelling_indobert_review_jogjakita.csv')
df['cleaning'] = df['cleaning'].astype('str')

# %%
#Importing libraries

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
indonesian_stop_words = stopwords.words('indonesian')
indonesian_stop_words.extend(['nya', 'ya', 'banget'])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df_positive = df[df['sentiment'] == 'positive']
df_neutral = df[df['sentiment'] == 'neutral']
df_negative = df[df['sentiment'] == 'negative']

positive_text = " ".join(content for content in df_positive['cleaning'])
neutral_text = " ".join(content for content in df_neutral['cleaning'])
negative_text = " ".join(content for content in df_negative['cleaning'])

positive_wordcloud = WordCloud(background_color = 'white', stopwords=indonesian_stop_words,
                               width = 800, height = 400).generate(positive_text)
neutral_wordcloud = WordCloud(background_color = 'white', stopwords=indonesian_stop_words,
                              width = 800, height = 400).generate(neutral_text)
negative_wordcloud = WordCloud(background_color = 'white', stopwords=indonesian_stop_words,
                               width = 800, height = 400).generate(negative_text)

plt.figure(figsize=(10, 5))
plt.imshow(positive_wordcloud, interpolation='bilinear')
plt.title('Wordcloud Positif')
plt.axis('off')
plt.show

plt.figure(figsize=(10, 5))
plt.imshow(neutral_wordcloud, interpolation='bilinear')
plt.title('Wordcloud Netral')
plt.axis('off')
plt.show

plt.figure(figsize=(10, 5))
plt.imshow(negative_wordcloud, interpolation='bilinear')
plt.title('wordcloud Negatif')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
